# %%
import logging
logging.root.handlers = []  # Jupyter messes up logging so needs a reset
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from smart_open import smart_open
import pandas as pd
import numpy as np
from numpy import random
import gensim
import nltk
from sklearn.cross_validation import train_test_split
from sklearn import linear_model
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model
from nltk.corpus import stopwords
import os, codecs
# %matplotlib inline

# %%
class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname
 
    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in codecs.open(os.path.join(self.dirname, fname)) :
                yield line.split()

# %%
sentences = MySentences('/home/bahbbc/Documents/teste-personalidade') # a memory-friendly iterator

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
model = gensim.models.Word2Vec(sentences, workers=50)
# Out:
# 2017-01-30 20:34:58,289 : INFO : collecting all words and their counts
# 2017-01-30 20:34:58,303 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-01-30 20:34:58,381 : INFO : PROGRESS: at sentence #10000, processed 98661 words, keeping 27955 word types
# 2017-01-30 20:34:58,440 : INFO : PROGRESS: at sentence #20000, processed 203143 words, keeping 49341 word types
# 2017-01-30 20:34:58,492 : INFO : PROGRESS: at sentence #30000, processed 292582 words, keeping 64869 word types
# 2017-01-30 20:34:58,553 : INFO : PROGRESS: at sentence #40000, processed 396167 words, keeping 81156 word types
# 2017-01-30 20:34:58,611 : INFO : PROGRESS: at sentence #50000, processed 493400 words, keeping 95005 word types
# 2017-01-30 20:34:58,667 : INFO : PROGRESS: at sentence #60000, processed 589134 words, keeping 108568 word types
# 2017-01-30 20:34:58,719 : INFO : PROGRESS: at sentence #70000, processed 676484 words, keeping 119972 word types
# 2017-01-30 20:34:58,782 : INFO : PROGRESS: at sentence #80000, processed 795993 words, keeping 133590 word types
# 2017-01-30 20:34:58,841 : INFO : PROGRESS: at sentence #90000, processed 906895 words, keeping 146634 word types
# 2017-01-30 20:34:58,897 : INFO : PROGRESS: at sentence #100000, processed 1002821 words, keeping 158366 word types
# 2017-01-30 20:34:58,957 : INFO : PROGRESS: at sentence #110000, processed 1103663 words, keeping 170182 word types
# 2017-01-30 20:34:59,020 : INFO : PROGRESS: at sentence #120000, processed 1195050 words, keeping 180481 word types
# 2017-01-30 20:34:59,077 : INFO : PROGRESS: at sentence #130000, processed 1285432 words, keeping 190921 word types
# 2017-01-30 20:34:59,133 : INFO : PROGRESS: at sentence #140000, processed 1376866 words, keeping 200532 word types
# 2017-01-30 20:34:59,190 : INFO : PROGRESS: at sentence #150000, processed 1474032 words, keeping 210517 word types
# 2017-01-30 20:34:59,250 : INFO : PROGRESS: at sentence #160000, processed 1576047 words, keeping 221053 word types
# 2017-01-30 20:34:59,308 : INFO : PROGRESS: at sentence #170000, processed 1670044 words, keeping 230518 word types
# 2017-01-30 20:34:59,377 : INFO : PROGRESS: at sentence #180000, processed 1779374 words, keeping 241337 word types
# 2017-01-30 20:34:59,435 : INFO : PROGRESS: at sentence #190000, processed 1870578 words, keeping 249592 word types
# 2017-01-30 20:34:59,495 : INFO : PROGRESS: at sentence #200000, processed 1960342 words, keeping 259200 word types
# 2017-01-30 20:34:59,555 : INFO : PROGRESS: at sentence #210000, processed 2051895 words, keeping 267875 word types
# 2017-01-30 20:34:59,623 : INFO : PROGRESS: at sentence #220000, processed 2157737 words, keeping 277623 word types
# 2017-01-30 20:34:59,681 : INFO : PROGRESS: at sentence #230000, processed 2250654 words, keeping 286187 word types
# 2017-01-30 20:34:59,700 : INFO : collected 288722 word types from a corpus of 2272383 raw words and 232478 sentences
# 2017-01-30 20:34:59,701 : INFO : Loading a fresh vocabulary
# 2017-01-30 20:35:00,002 : INFO : min_count=5 retains 34378 unique words (11% of original 288722, drops 254344)
# 2017-01-30 20:35:00,002 : INFO : min_count=5 leaves 1926717 word corpus (84% of original 2272383, drops 345666)
# 2017-01-30 20:35:00,108 : INFO : deleting the raw counts dictionary of 288722 items
# 2017-01-30 20:35:00,124 : INFO : sample=0.001 downsamples 38 most-common words
# 2017-01-30 20:35:00,125 : INFO : downsampling leaves estimated 1580285 word corpus (82.0% of prior 1926717)
# 2017-01-30 20:35:00,126 : INFO : estimated required memory for 34378 words and 100 dimensions: 44691400 bytes
# 2017-01-30 20:35:00,271 : INFO : resetting layer weights
# 2017-01-30 20:35:01,048 : INFO : training model with 50 workers on 34378 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2017-01-30 20:35:01,052 : INFO : expecting 232478 sentences, matching count from corpus used for vocabulary survey
# 2017-01-30 20:35:02,383 : INFO : PROGRESS: at 5.47% examples, 426812 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:03,392 : INFO : PROGRESS: at 13.59% examples, 536352 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:04,395 : INFO : PROGRESS: at 23.24% examples, 608591 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:05,398 : INFO : PROGRESS: at 31.60% examples, 622548 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:06,402 : INFO : PROGRESS: at 40.13% examples, 630780 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:07,409 : INFO : PROGRESS: at 49.45% examples, 650933 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:08,413 : INFO : PROGRESS: at 58.21% examples, 653791 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:09,414 : INFO : PROGRESS: at 65.82% examples, 646481 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:10,423 : INFO : PROGRESS: at 74.67% examples, 652737 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:11,437 : INFO : PROGRESS: at 82.48% examples, 647564 words/s, in_qsize 0, out_qsize 1
# 2017-01-30 20:35:12,459 : INFO : PROGRESS: at 90.59% examples, 647248 words/s, in_qsize 0, out_qsize 0
# 2017-01-30 20:35:13,448 : INFO : worker thread finished; awaiting finish of 49 more threads
# 2017-01-30 20:35:13,451 : INFO : worker thread finished; awaiting finish of 48 more threads
# 2017-01-30 20:35:13,452 : INFO : worker thread finished; awaiting finish of 47 more threads
# 2017-01-30 20:35:13,453 : INFO : worker thread finished; awaiting finish of 46 more threads
# 2017-01-30 20:35:13,455 : INFO : worker thread finished; awaiting finish of 45 more threads
# 2017-01-30 20:35:13,458 : INFO : worker thread finished; awaiting finish of 44 more threads
# 2017-01-30 20:35:13,459 : INFO : worker thread finished; awaiting finish of 43 more threads
# 2017-01-30 20:35:13,460 : INFO : worker thread finished; awaiting finish of 42 more threads
# 2017-01-30 20:35:13,462 : INFO : worker thread finished; awaiting finish of 41 more threads
# 2017-01-30 20:35:13,463 : INFO : worker thread finished; awaiting finish of 40 more threads
# 2017-01-30 20:35:13,465 : INFO : worker thread finished; awaiting finish of 39 more threads
# 2017-01-30 20:35:13,466 : INFO : worker thread finished; awaiting finish of 38 more threads
# 2017-01-30 20:35:13,477 : INFO : PROGRESS: at 100.00% examples, 653325 words/s, in_qsize 0, out_qsize 6
# 2017-01-30 20:35:13,480 : INFO : worker thread finished; awaiting finish of 37 more threads
# 2017-01-30 20:35:13,486 : INFO : worker thread finished; awaiting finish of 36 more threads
# 2017-01-30 20:35:13,487 : INFO : worker thread finished; awaiting finish of 35 more threads
# 2017-01-30 20:35:13,489 : INFO : worker thread finished; awaiting finish of 34 more threads
# 2017-01-30 20:35:13,490 : INFO : worker thread finished; awaiting finish of 33 more threads
# 2017-01-30 20:35:13,494 : INFO : worker thread finished; awaiting finish of 32 more threads
# 2017-01-30 20:35:13,499 : INFO : worker thread finished; awaiting finish of 31 more threads
# 2017-01-30 20:35:13,501 : INFO : worker thread finished; awaiting finish of 30 more threads
# 2017-01-30 20:35:13,502 : INFO : worker thread finished; awaiting finish of 29 more threads
# 2017-01-30 20:35:13,503 : INFO : worker thread finished; awaiting finish of 28 more threads
# 2017-01-30 20:35:13,503 : INFO : worker thread finished; awaiting finish of 27 more threads
# 2017-01-30 20:35:13,504 : INFO : worker thread finished; awaiting finish of 26 more threads
# 2017-01-30 20:35:13,506 : INFO : worker thread finished; awaiting finish of 25 more threads
# 2017-01-30 20:35:13,507 : INFO : worker thread finished; awaiting finish of 24 more threads
# 2017-01-30 20:35:13,508 : INFO : worker thread finished; awaiting finish of 23 more threads
# 2017-01-30 20:35:13,509 : INFO : worker thread finished; awaiting finish of 22 more threads
# 2017-01-30 20:35:13,511 : INFO : worker thread finished; awaiting finish of 21 more threads
# 2017-01-30 20:35:13,512 : INFO : worker thread finished; awaiting finish of 20 more threads
# 2017-01-30 20:35:13,513 : INFO : worker thread finished; awaiting finish of 19 more threads
# 2017-01-30 20:35:13,514 : INFO : worker thread finished; awaiting finish of 18 more threads
# 2017-01-30 20:35:13,514 : INFO : worker thread finished; awaiting finish of 17 more threads
# 2017-01-30 20:35:13,516 : INFO : worker thread finished; awaiting finish of 16 more threads
# 2017-01-30 20:35:13,517 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2017-01-30 20:35:13,518 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2017-01-30 20:35:13,519 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2017-01-30 20:35:13,519 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2017-01-30 20:35:13,520 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2017-01-30 20:35:13,521 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2017-01-30 20:35:13,521 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2017-01-30 20:35:13,522 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2017-01-30 20:35:13,523 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2017-01-30 20:35:13,524 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2017-01-30 20:35:13,525 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2017-01-30 20:35:13,525 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2017-01-30 20:35:13,526 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-01-30 20:35:13,527 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-01-30 20:35:13,527 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-01-30 20:35:13,528 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-01-30 20:35:13,529 : INFO : training on 11361915 raw words (7901834 effective words) took 12.2s, 650123 effective words/s

# %%
model.save('/home/bahbbc/Documents/teste-personalidade/personality_1')
# Out:
# 2017-01-30 20:36:04,021 : INFO : saving Word2Vec object under /home/bahbbc/Documents/teste-personalidade/personality_1, separately None
# 2017-01-30 20:36:04,023 : INFO : not storing attribute syn0norm
# 2017-01-30 20:36:04,025 : INFO : not storing attribute cum_table
# 2017-01-30 20:36:05,091 : INFO : saved /home/bahbbc/Documents/teste-personalidade/personality_1

# %%
model = gensim.models.Word2Vec.load('/home/bahbbc/Documents/teste-personalidade/personality_1')
#model = Word2Vec.load_word2vec_format('/home/bahbbc/Documents/teste-personalidade/personality_1',binary=True)
model.init_sims(replace=True)
# Out:
# 2017-01-30 21:14:00,015 : INFO : loading Word2Vec object from /home/bahbbc/Documents/teste-personalidade/personality_1
# 2017-01-30 21:14:00,241 : INFO : loading wv recursively from /home/bahbbc/Documents/teste-personalidade/personality_1.wv.* with mmap=None
# 2017-01-30 21:14:00,242 : INFO : setting ignored attribute syn0norm to None
# 2017-01-30 21:14:00,243 : INFO : setting ignored attribute cum_table to None
# 2017-01-30 21:14:00,244 : INFO : loaded /home/bahbbc/Documents/teste-personalidade/personality_1
# 2017-01-30 21:14:00,327 : INFO : precomputing L2-norms of word weight vectors

# %%
type(model)
# Out:
# gensim.models.word2vec.Word2Vec

# %%
from itertools import islice
list(islice(model.vocab, 13000, 13020))
# Out:
# 2017-01-30 21:14:01,931 : WARNING : direct access to vocab will not be supported in future gensim releases, please use model.wv.vocab
# ['"Simone',
#  'adjetivos',
#  'if',
#  'm\xc3\xaddia.',
#  'equipes',
#  'Bevilacqua',
#  'Wiliam',
#  'livrar',
#  'criativas',
#  'Gean',
#  'estadual',
#  'pesquisas,',
#  '"COMO',
#  '\xf0\x9f\x92\x9a\xf0\x9f\x92\x9a\xf0\x9f\x92\x9a\xf0\x9f\x92\x9a',
#  'dizem.',
#  'dizem,',
#  'criativa,',
#  '#loveit',
#  'equipe!',
#  'exig\xc3\xaancia']

# %%
print(model)
print(model.wv.vocab)
# Out:
# Word2Vec(vocab=34378, size=100, alpha=0.025)
# {u'Ele,': <gensim.models.word2vec.Vocab object at 0x7fd26f1bded0>, u'Ele.': <gensim.models.word2vec.Vocab object at 0x7fd26f1bdf50>, u'gastar,': <gensim.models.word2vec.Vocab object at 0x7fd26f1bd350>, u'instalada': <gensim.models.word2vec.Vocab object at 0x7fd26f1bdfd0>, u'vcs."': <gensim.models.word2vec.Vocab object at 0x7fd26f1bd390>, u'internet...': <gensim.models.word2vec.Vocab object at 0x7fd26f1bd050>, u'prazo': <gensim.models.word2vec.Vocab object at 0x7fd26f1bdf90>, u'Moreira': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab590>, u'far\xe3o': <gensim.models.word2vec.Vocab object at 0x7fd26f5abcd0>, u'igual': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab310>, u'apare\xe7am': <gensim.models.word2vec.Vocab object at 0x7fd26f5abad0>, u'Jornada': <gensim.models.word2vec.Vocab object at 0x7fd26f5abe10>, u'Valle': <gensim.models.word2vec.Vocab object at 0x7fd26f5abb90>, u'Jerusal\xe9m': <gensim.models.word2vec.Vocab object at 0x7fd26f5abbd0>, u'Eles': <gensim.models.word2vec.Vocab object at 0x7fd26f5abc10>, u'atingiu': <gensim.models.word2vec.Vocab object at 0x7fd26f5abc50>, u'Livraria': <gensim.models.word2vec.Vocab object at 0x7fd26f5abc90>, u'Seguran\xe7a': <gensim.models.word2vec.Vocab object at 0x7fd26f5abd90>, u'Saca': <gensim.models.word2vec.Vocab object at 0x7fd26f5abdd0>, u'come\xe7ou...': <gensim.models.word2vec.Vocab object at 0x7fd26f5abd10>, u'Saco': <gensim.models.word2vec.Vocab object at 0x7fd26f5abd50>, u'v\xea-la': <gensim.models.word2vec.Vocab object at 0x7fd2729f7490>, u'PQP': <gensim.models.word2vec.Vocab object at 0x7fd26f5abed0>, u'Filha,': <gensim.models.word2vec.Vocab object at 0x7fd292b63d90>, u'planejamento': <gensim.models.word2vec.Vocab object at 0x7fd26f5abfd0>, u'caramelo': <gensim.models.word2vec.Vocab object at 0x7fd26f5abf90>, u'\u2705': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab850>, u'Passando': <gensim.models.word2vec.Vocab object at 0x7fd293e7bd10>, u'e,': <gensim.models.word2vec.Vocab object at 0x7fd2729f7510>, u'Recebendo': <gensim.models.word2vec.Vocab object at 0x7fd26f5aba90>, u'bater,': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab950>, u'\U0001f60f': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab9d0>, u'assumimos': <gensim.models.word2vec.Vocab object at 0x7fd26f5aba10>, u'p\xe9ssimas': <gensim.models.word2vec.Vocab object at 0x7fd26f5abb10>, u'ensinou.': <gensim.models.word2vec.Vocab object at 0x7fd26f5abb50>, u'datas,': <gensim.models.word2vec.Vocab object at 0x7fd26f5abe50>, u'2011...': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab8d0>, u'guardados': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab5d0>, u'xod\xf3': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab650>, u'preocupada,': <gensim.models.word2vec.Vocab object at 0x7fd292ede4d0>, u'derrotado': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab6d0>, u'mestre!': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab710>, u'apelidos': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab750>, u'"F\xe1bio': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab790>, u'mestre,': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab7d0>, u'Falar': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab810>, u'dirigindo': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab890>, u'mais.': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab910>, u'Renata,': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab150>, u'"""S\xe3o': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab1d0>, u'Falam': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab190>, u'Constitui\xe7\xe3o': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab290>, u'linha': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab250>, u'mestres': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab390>, u'kids': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab350>, u'Rodrigues...': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab410>, u'acertar': <gensim.models.word2vec.Vocab object at 0x7fd26f5ab3d0>, u'""dar': <gensim.models.word2vec. ...

# %%
print(model.similarity('hj', 'hoje'))
# Out:
# 0.804962995363

# %%
print(model.most_similar(positive=['rsrsrs', 'kkk']))
# Out:
# [('Kkkk', 0.9536061882972717), ('Hahahaha', 0.9516220092773438), ('Kkkkkk', 0.9471272230148315), ('kkkk"', 0.9449805021286011), ('kkk"', 0.9388039112091064), ("'-'", 0.9386096000671387), ('Kkk', 0.9377967715263367), ('rsrs', 0.9362626075744629), ('kkkkkkk', 0.9360034465789795), ('xD', 0.9358361959457397)]

# %%
print(model.most_similar(positive=['=O', ':D']))
# Out:
# [('hihi', 0.936150848865509), ('Lugar', 0.9317181706428528), (':DD', 0.9315298795700073), ('Ver\xc3\xb4nica', 0.9295929074287415), ('hoje!!!', 0.9288181662559509), ('TOP', 0.9269366264343262), ('\xf0\x9f\x90\xb6', 0.9261671900749207), ('o/', 0.9251559376716614), ('LZT', 0.9251223206520081), ('bonitinha', 0.9243689179420471)]

# %%
print(model.most_similar(positive=['gato', 'cachorro']))
# Out:
# [('calor', 0.9144645929336548), ('coment\xc3\xa1rio', 0.9141213893890381), ('velho', 0.9131175875663757), ('riso', 0.9104961156845093), ('neg\xc3\xb3cio', 0.90016770362854), ('erro', 0.8966143131256104), ('menino', 0.8935321569442749), ('peito', 0.8929440975189209), ('livro,', 0.8927930593490601), ('destino', 0.8913571834564209)]

# %% [markdown]
# ### Verify model with personality

# %%
df = pd.read_csv('~/personality-normalized-word2vec.csv', encoding='utf_8')
df = df.dropna()
df['isExtr'].apply(lambda x: len(x.split(' '))).sum()
# Out:
# 3186

# %%
df.isExtr.value_counts()
# Out:
#  na      542
#  no      275
#  yes     245
# Name: isExtr, dtype: int64

# %%
train_data, test_data = train_test_split(df, test_size=0.3, random_state=42)

# %%
len(test_data)
# Out:
# 319

# %%
test_data.isExtr.value_counts()
# Out:
#  na      165
#  no       79
#  yes      75
# Name: isExtr, dtype: int64

# %% [markdown]
# ### Evaluation code

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(3)
    target_names = ['na', 'no', 'yes']
    plt.xticks(tick_marks, target_names, rotation=45)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def evaluate_prediction(predictions, target, title="Confusion matrix"):
    print('accuracy %s' % accuracy_score(target, predictions))
    cm = confusion_matrix(target, predictions)
    print('confusion matrix\n %s' % cm)
    print('(row=expected, col=predicted)')
    
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plot_confusion_matrix(cm_normalized, title + ' Normalized')

# %%
def predict(vectorizer, classifier, data):
    data_features = vectorizer.transform(data['formatted_text'])
    predictions = classifier.predict(data_features)
    target = data['isExtr']
    evaluate_prediction(predictions, target)

# %% [markdown]
# ### Word2Vec model training

# %%
def word_averaging(wv, words):
    all_words, mean = set(), []
    
    for word in words:
        if isinstance(word, np.ndarray):
            mean.append(word)
        elif word in wv.wv.vocab:
            mean.append(wv.wv.syn0norm[wv.wv.vocab[word].index])
            all_words.add(wv.wv.vocab[word].index)

    if not mean:
        logging.warning("cannot compute similarity with no input %s", words)
        # FIXME: remove these examples in pre-processing
        return np.zeros(wv.layer_size,)

    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return mean

def  word_averaging_list(wv, text_list):
    return np.vstack([word_averaging(wv, review) for review in text_list ])

# %%
def w2v_tokenize_text(text):
    tokens = []
    for sent in nltk.sent_tokenize(text, language='portuguese'):
        for word in nltk.word_tokenize(sent, language='portuguese'):
            if len(word) < 2:
                continue
            tokens.append(word)
    return tokens

# %%
test_tokenized = test_data.apply(lambda r: w2v_tokenize_text(r['formatted_text']), axis=1).values
train_tokenized = train_data.apply(lambda r: w2v_tokenize_text(r['formatted_text']), axis=1).values

# %%
# %%time
X_train_word_average = word_averaging_list(model,train_tokenized)
X_test_word_average = word_averaging_list(model,test_tokenized)
# Out:
# 2017-01-30 20:51:56,208 : WARNING : cannot compute similarity with no input []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-46f166754d45> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'X_train_word_average = word_averaging_list(model,train_tokenized)\nX_test_word_average = word_averaging_list(model,test_tokenized)')
#
# /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /usr/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1178         else:
#    1179             st = clock2()
# -> 1180             exec(code, glob, local_ns)
#    1181             end = clock2()
#    1182             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-18-ee85d7a41b53> in word_averaging_list(wv, text_list)
#      18
#      19 def  word_averaging_list(wv, text_list):
# ---> 20     return np.vstack([word_averaging(wv, review) for review in text_list ])
#
# <ipython-input-18-ee85d7a41b53> in word_averaging(wv, words)
#      12         logging.warning("cannot compute similarity with no input %s", words)
#      13         # FIXME: remove these examples in pre-processing
# ---> 14         return np.zeros(wv.layer_size,)
#      15
#      16     mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
#
# AttributeError: 'Word2Vec' object has no attribute 'layer_size'

# %%
# %%time
knn_naive_dv = KNeighborsClassifier(n_neighbors=3, n_jobs=1, algorithm='brute', metric='cosine' )
knn_naive_dv.fit(X_train_word_average, train_data.tag)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-0682e1f9a838> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u"knn_naive_dv = KNeighborsClassifier(n_neighbors=3, n_jobs=1, algorithm='brute', metric='cosine' )\nknn_naive_dv.fit(X_train_word_average, train_data.tag)")
#
# /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /usr/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1178         else:
#    1179             st = clock2()
# -> 1180             exec(code, glob, local_ns)
#    1181             end = clock2()
#    1182             out = None
#
# <timed exec> in <module>()
#
# NameError: name 'X_train_word_average' is not defined

# %%
# %%time
logreg = linear_model.LogisticRegression(n_jobs=1, C=1e5)

logreg = logreg.fit(X_train_word_average, train_data['isExtr'])
predicted = logreg.predict(X_test_word_average)

# %%
evaluate_prediction(predicted, test_data.isExtr)
